# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd 
import datetime # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

df=pd.read_csv('../input/dates_out.csv')
df=df.head(400)
# Out:
# /kaggle/input/dates_out.csv

# %%
for i in range(0,400):
    x=df['sentence'][i]
    x=x.lower()
    df['sentence'][i]=x
df
# Out:
#                    sentence Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          seventeenth july        NaN        NaN        NaN        NaN
# 1               eight april        NaN        NaN        NaN        NaN
# 2              24 september        NaN        NaN        NaN        NaN
# 3                     1 may        NaN        NaN        NaN        NaN
# 4                    25 may        NaN        NaN        NaN        NaN
# ..                      ...        ...        ...        ...        ...
# 395      22nd of march 1998        NaN        NaN        NaN        NaN
# 396       2nd of april 2027        NaN        NaN        NaN        NaN
# 397    nineth of april 2027        NaN        NaN        NaN        NaN
# 398  three of december 2023        NaN        NaN        NaN        NaN
# 399     five of august 2032        NaN        NaN        NaN        NaN
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 288  \
# 0          NaN        NaN        NaN        NaN        NaN  ...          NaN
# 1          NaN        NaN        NaN        NaN        NaN  ...          NaN
# 2          NaN        NaN        NaN        NaN        NaN  ...          NaN
# 3          NaN        NaN        NaN        NaN        NaN  ...          NaN
# 4          NaN        NaN        NaN        NaN        NaN  ...          NaN
# ..         ...        ...        ...        ...        ...  ...          ...
# 395        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 396        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 397        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 398        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 399        NaN        NaN        NaN        NaN        NaN  ...          NaN
#
#     Unnamed: 289 Unnamed: 290 Unnamed: 291 Unnamed: 292 Unnamed: 293  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 395          NaN          NaN          NaN          NaN          NaN
# 396          NaN          NaN          NaN          NaN          NaN
# 397          NaN          NaN          NaN          NaN          NaN
# 398          NaN          NaN          NaN          NaN          NaN
# 399          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 294 Unnamed: 295 Unnamed: 296 Unnamed: 297
# 0            NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...
# 395          NaN          NaN          NaN          NaN
# 396          NaN          NaN          NaN          NaN
# 397          NaN          NaN          NaN          NaN
# 398          NaN          NaN          NaN          NaN
# 399          NaN          NaN          NaN          NaN
#
# [400 rows x 298 columns]

# %%
import re
dic={'jan ':'1','january':'1','feb ':'2','february':'2','mar ':'3','march':'3','apr ':'4','april':'4','may':'5','jun ':'6','june':'6','jul ':'7','july':'7','aug ':'8','august':'8','sep ':'9','sept ':'9','september':'9','oct ':'10','october':'10','nov ':'11','november':'11','dec ':'12','december':'12'}

dates={'one':'1','first':'1','second':'2','two':'2','three':'3','third':'3','four':'4','fourth':'4','five':'5','fifth':'5','six':'6','sixth':'6','seven':'7','seventh':'7','eight':'8','eighth':'8','nine':'9','nineth':'9','ten':'10','tenth':'10','eleven':'11','twelve':'12','twelfth':'12','thirteen':'13','thirteenth':'13','fourteenth':'14','fifteenth':'15','sixteenth':'16','fourteen':'14','fifteen':'15','sixteen':'16','seventeen':'17','seventeenth':'17','eighteen':'18','eighteenth':'18','nineteen':'19','nineteenth':'19','twenty':'20','twenty one':'21','twenty first':'21','twenty second':'22','twenty two':'22','twenty third':'23','twenty three':'23','twenty four':'24','twenty five':'25','twenty six':'26','twenty seven':'27','twenty eight':'28','twenty nine':'29','thirty':'30','thirty first':'31','thirty one':'31'}

# %%
#s="13th dec "
t=0
for ii in df['sentence']:
    ii=ii+" "
    #print("iiiiiiiiii   ",ii)
    prop=""
    date_int=0
    month_int=0

    date_num=re.search(r'(^([0-9]{1,2}))',ii)
    if date_num:
        a=date_num.group(1)
        #print(a)
        date_int=int(a)
        prop=prop+a+"-"
        
    date_text=re.search(r'(^((one|first|second|two|three|third|four|fourth|five|fifth|six|sixth|seven|seventh|eighth|eight|nine|nineth|ten|tenth|eleven|eleventh|twelve|twelfth|thirteen|thirteenth|fourteenth|fifteenth|sixteenth|seventeenth|fourteen|fifteen|sixteen|seventeen|eighteen|eighteenth|nineteen|nineteenth|twenty|twenty\sone|twenty\sfirst|twenty\ssecond|twenty\stwo|twenty\sthird|twenty\sthree|twenty\sfour|twenty\sfive|twenty\ssix|twenty\sseven|twenty\seight|twenty\snine|thirty|thirty\sfirst|thirty\sone)?(\s)?(-|\s)?(st|nd|rd|th|of)?(\s)?(jan\s|january|feb\s|february|mar\s|march|apr\s|april|may|jun\s|june|jul\s|july|aug\s|august|sep\s|sept|september|oct\s|october|nov\s|november|dec\s|december)))',ii)
    if date_text:
        date_out=date_text.group(3)
        for l,m in dates.items():
            if l==date_out:
                prop=prop+m+"-"
        
        
        
    month=re.search(r'(jan\s|january|feb\s|february|mar\s|march|apr\s|april|may|jun\s|june|jul\s|july|aug\s|august|sep\s|sept\s|september|oct\s|october|nov\s|november|dec\s|december)',ii)
    if month:
        b=month.group(1)
        #print("bbbbb",b)
        for i,j in dic.items():
            #print("iijjjjjjjjjjjj",i)
            if b==i:
                prop=prop+j+'-'
                month_int=int(j)
                #print(prop)
                break
    year=re.search(r'(([0-9]{1,4}(\s))$)',ii)
    if year:
        t=1
        yearr=year.group(0)
        prop=prop+yearr
        print(prop)
    if t!=1:
        monthh = datetime.datetime.now().strftime("%m")
        mon=int(monthh)
        yeear = datetime.datetime.now().strftime("%Y")
        yr=int(yeear)
        if mon>month_int:
            yr=yr+1
            yrr=str(yr)
            prop=prop+yrr
            print(prop)
        else:
            prop=prop+yeear
            print(prop)
# Out:
# 17-7-2020
# 8-4-2020
# 24-9-2020
# 1-5-2020
# 25-5-2020
# 12-7-2020
# 13-5-2020
# 23-1-2020
# 1-11-2020
# 19-2-2020
# 15-4-2020
# 16-10-2020
# 8-4-2020
# 30-11-2020
# 12-8-2020
# 18-6-2020
# 21-2-2020
# 3-11-2020
# 10-8-2020
# 28-2-2020
# 13-11-2020
# 6-12-2019
# 21-3-2020
# 18-9-2020
# 18-11-2020
# 19-7-2020
# 23-11-2020
# 23-4-2020
# 6-8-2020
# 27-3-2020
# 11-10-2020
# 3-9-2020
# 22-6-2020
# 28-1-2020
# 16-1-2020
# 28-1-2020
# 26-9-2020
# 19-12-2019
# 23-8-2020
# 19-5-2020
# 6-12-2019
# 11-9-2020
# 1-5-2020
# 22-1-2020
# 6-1-2020
# 30-8-2020
# 5-2-2020
# 4-8-2020
# 14-5-2020
# 18-8-2020
# 8-8-2020
# 14-4-2020
# 15-12-2019
# 5-12-2019
# 21-2-2020
# 3-9-2020
# 20-8-2020
# 12-1-2020
# 11-12-2019
# 5-2-2020
# 3-11-2020
# 7-12-2019
# 10-12-2019
# 3-10-2020
# 8-9-2020
# 19-1-2020
# 3-4-2020
